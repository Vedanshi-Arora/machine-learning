# %%
import pandas as pd

# %%
df=pd.read_csv('com.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# Name          6 non-null object
# Department    4 non-null object
# Manager       4 non-null object
# Salary        6 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 272.0+ bytes

# %%
df
# Out:
#             Name Department      Manager  Salary
# 0     Robin Hood        NaN          NaN     200
# 1  Arsene Wenger        Bar   Friar Tuck      50
# 2     Friar Tuck        Foo   Robin Hood     100
# 3    Little John        Foo   Robin Hood     100
# 4  Sam Allardyce        NaN          NaN     250
# 5  Dimi Berbatov        Foo  Little John      50

# %%
df.head(3) #to show the top 3 rows
# Out:
#             Name Department     Manager  Salary
# 0     Robin Hood        NaN         NaN     200
# 1  Arsene Wenger        Bar  Friar Tuck      50
# 2     Friar Tuck        Foo  Robin Hood     100

# %%
df['Salary'] #particular column is required
# Out:
# 0    200
# 1     50
# 2    100
# 3    100
# 4    250
# 5     50
# Name: Salary, dtype: int64

# %%
#for selecting rows and columns:
# numpy's concepts can be used
# df.iloc is used, iloc refers to index location
df.iloc[0:,0]
# Out:
# 0       Robin Hood
# 1    Arsene Wenger
# 2       Friar Tuck
# 3      Little John
# 4    Sam Allardyce
# 5    Dimi Berbatov
# Name: Name, dtype: object

# %%
df.iloc[0:,0:2]
# Out:
#             Name Department
# 0     Robin Hood        NaN
# 1  Arsene Wenger        Bar
# 2     Friar Tuck        Foo
# 3    Little John        Foo
# 4  Sam Allardyce        NaN
# 5  Dimi Berbatov        Foo

# %%
df['Salary'].max()  #to find maximum value
# Out:
# 250

# %%
df['Salary'].min()  #to find minimum value
# Out:
# 50

# %%
df['Salary'].sum()
# Out:
# 750

# %%
df['Salary'].mean()
# Out:
# 125.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
x=df

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame
