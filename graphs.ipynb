# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import time

# %%
x=[4,7,8,9,11,5]

# %%
y=[13,23,5,7,9,10]

# %%
player=['virat','dhoni','vijay','dhawan']

# %%
runs=[120,44,77,33]

# %%
x=[4,7,8,9,11,5]
y=[13,23,5,7,9,10]
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(color='green')
plt.legend()
plt.plot(x,y)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x=[4,7,8,9,11,5]
y=[13,23,5,7,9,10]

# %%
plt.scatter(x,y)

# %%
player=['virat','dhoni','vijay','dhawan']
runs=[120,44,77,33]
exp=[0.1,0,0,0.2]

# %%
plt.pie(runs,labels=player)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f68750089e8>,
#   <matplotlib.patches.Wedge at 0x7f6875008eb8>,
#   <matplotlib.patches.Wedge at 0x7f68750143c8>,
#   <matplotlib.patches.Wedge at 0x7f6875014898>],
#  [Text(0.21305286529944611, 1.0791702722868604, 'virat'),
#   Text(-1.092777526229224, -0.12584624812976195, 'dhoni'),
#   Text(-0.07561366497327134, -1.0973980926123892, 'vijay'),
#   Text(1.022196039429051, -0.40634376699484664, 'dhawan')])

# %%
plt.pie(runs,labels=player,explode=exp)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6874fcbc88>,
#   <matplotlib.patches.Wedge at 0x7f6874fd6198>,
#   <matplotlib.patches.Wedge at 0x7f6874fd6668>,
#   <matplotlib.patches.Wedge at 0x7f6874fd6b38>],
#  [Text(0.23242130759939578, 1.177276660676575, 'virat'),
#   Text(-1.092777526229224, -0.12584624812976195, 'dhoni'),
#   Text(-0.07561366497327134, -1.0973980926123892, 'vijay'),
#   Text(1.2080498647797875, -0.48022445190300056, 'dhawan')])

# %%
plt.pie(runs,labels=player,explode=exp,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f6874f65860>,
#   <matplotlib.patches.Wedge at 0x7f6874f65fd0>,
#   <matplotlib.patches.Wedge at 0x7f6874f6f780>,
#   <matplotlib.patches.Wedge at 0x7f6874f6fef0>],
#  [Text(0.23242130759939578, 1.177276660676575, 'virat'),
#   Text(-1.092777526229224, -0.12584624812976195, 'dhoni'),
#   Text(-0.07561366497327134, -1.0973980926123892, 'vijay'),
#   Text(1.2080498647797875, -0.48022445190300056, 'dhawan')])
